# %%
import pandas as pd

# %%
df = pd.read_csv('data/location.csv')
stations = pd.read_csv('data/bangkok_bts_stations.csv')

# %%
df['name'].isna().sum()
# Out:
# 2121

# %%
df.isna().sum()
# Out:
# lat        0
# lon        0
# name    2121
# type       0
# dtype: int64

# %%
# df.dropna(subset=['name'], inplace=True)
df.describe()
# Out:
#                lat          lon
# count  4071.000000  4071.000000
# mean     13.745198   100.602581
# std       0.081880     0.086191
# min      13.415033   100.500019
# 25%      13.706860   100.531842
# 50%      13.751196   100.579362
# 75%      13.803483   100.647756
# max      13.899999   100.998290

# %%
df['type'].value_counts()
# Out:
# type
# BusStop             3002
# 7-Eleven             842
# place_of_worship     227
# Name: count, dtype: int64

# %%
df.head(20)
# Out:
#           lat         lon                                 name  \
# 0   13.728278  100.533045                             7-Eleven
# 1   13.728451  100.535881                             7-Eleven
# 2   13.728859  100.535664                             7-Eleven
# 3   13.726931  100.541617                             7-Eleven
# 4   13.727977  100.540875                 สวนลุมพินี (ประตู 3)
# 5   13.819590  100.696324                  วัดราษฎร์ศรัทธาธรรม
# 6   13.681734  100.680519                         วัดทุ่งลานนา
# 7   13.740543  100.530054              โรงเรียนเตรียมอุดมศึกษา
# 8   13.744355  100.530363                            มาบุญครอง
# 9   13.738198  100.529702                 จุฬาฯ (ลานพระบรมรูป)
# 10  13.736174  100.529159                จุฬาฯ (คณะนิติศาสตร์)
# 11  13.743514  100.530487                             โอสถศาลา
# 12  13.741726  100.535096              โรงพยาบาลสัตว์เล็กจุฬาฯ
# 13  13.739285  100.534724            โรงเรียนสาธิต มศว ปทุมวัน
# 14  13.733706  100.533885                 จุฬาฯ (คณะรัฐศาสตร์)
# 15  13.744697  100.535583                         แยกเฉลิมเผ่า
# 16  13.765756  100.538073  อนุสาวรีย์ชัยสมรภูมิ (เกาะพหลโยธิน)
# 17  13.764699  100.537458   อนุสาวรีย์ชัยสมรภูมิ (เกาะราชวิถี)
# 18  13.764164  100.538472     อนุสาวรีย์ชัยสมรภูมิ (เกาะพญาไท)
# 19  13.765306  100.539187    อนุสาวรีย์ชัยสมรภูมิ (เกาะดินแดง)
#
#                 type
# 0           7-Eleven
# 1           7-Eleven
# 2           7-Eleven
# 3           7-Eleven
# 4            BusStop
# 5   place_of_worship
# 6   place_of_worship
# 7            BusStop
# 8            BusStop
# 9            BusStop
# 10           BusStop
# 11           BusStop
# 12           BusStop
# 13           BusStop
# 14           BusStop
# 15           BusStop
# 16           BusStop
# 17           BusStop
# 18           BusStop
# 19           BusStop

# %%
stations.head()
# Out:
#      Station Name (Thai)                    Coordinates  \
# 0           สถานีบางซ่อน           13.8202°N 100.5324°E
# 1           สถานีบางหว้า     13.7206250°N 100.4578694°E
# 2           สถานีทองหล่อ     13.7242444°N 100.5785583°E
# 3      สถานีลาดพร้าว 101           13.7747°N 100.6298°E
# 4  สถานีกระทรวงสาธารณสุข  13.84870092°N, 100.51469189°E
#
#                          Lines
# 0              ['Purple Line']
# 1  ['Silom Line', 'Blue Line']
# 2           ['Sukhumvit Line']
# 3              ['Yellow Line']
# 4              ['Purple Line']

# %%
stations['Coordinates'] = stations['Coordinates'].str.replace(',','').str.replace('°N', ',').str.replace('°E', '')

stations.head()
# Out:
#      Station Name (Thai)                Coordinates  \
# 0           สถานีบางซ่อน          13.8202, 100.5324
# 1           สถานีบางหว้า    13.7206250, 100.4578694
# 2           สถานีทองหล่อ    13.7242444, 100.5785583
# 3      สถานีลาดพร้าว 101          13.7747, 100.6298
# 4  สถานีกระทรวงสาธารณสุข  13.84870092, 100.51469189
#
#                          Lines
# 0              ['Purple Line']
# 1  ['Silom Line', 'Blue Line']
# 2           ['Sukhumvit Line']
# 3              ['Yellow Line']
# 4              ['Purple Line']

# %%
stations[['lat', 'lon']] = stations['Coordinates'].str.split(",", expand=True).astype(float)

stations.head()
# Out:
#      Station Name (Thai)                Coordinates  \
# 0           สถานีบางซ่อน          13.8202, 100.5324
# 1           สถานีบางหว้า    13.7206250, 100.4578694
# 2           สถานีทองหล่อ    13.7242444, 100.5785583
# 3      สถานีลาดพร้าว 101          13.7747, 100.6298
# 4  สถานีกระทรวงสาธารณสุข  13.84870092, 100.51469189
#
#                          Lines        lat         lon
# 0              ['Purple Line']  13.820200  100.532400
# 1  ['Silom Line', 'Blue Line']  13.720625  100.457869
# 2           ['Sukhumvit Line']  13.724244  100.578558
# 3              ['Yellow Line']  13.774700  100.629800
# 4              ['Purple Line']  13.848701  100.514692

# %%
stations.drop(columns=['Coordinates', 'Lines'], inplace=True)
stations.head()
# Out:
#      Station Name (Thai)        lat         lon
# 0           สถานีบางซ่อน  13.820200  100.532400
# 1           สถานีบางหว้า  13.720625  100.457869
# 2           สถานีทองหล่อ  13.724244  100.578558
# 3      สถานีลาดพร้าว 101  13.774700  100.629800
# 4  สถานีกระทรวงสาธารณสุข  13.848701  100.514692

# %%
stations['type'] = 'RapidTransitStation'

# %%
locations =pd.concat([df,stations.rename(columns={'Station Name (Thai)':'name', 'Coordinates':'coords'})], ignore_index=True)

# %%
locations.head()
# Out:
#          lat         lon                  name      type
# 0  13.728278  100.533045              7-Eleven  7-Eleven
# 1  13.728451  100.535881              7-Eleven  7-Eleven
# 2  13.728859  100.535664              7-Eleven  7-Eleven
# 3  13.726931  100.541617              7-Eleven  7-Eleven
# 4  13.727977  100.540875  สวนลุมพินี (ประตู 3)   BusStop

# %%
locations.tail()
# Out:
#           lat       lon                   name                 type
# 4245  13.9905  100.6022            สถานีรังสิต  RapidTransitStation
# 4246  13.8748  100.4559  สถานีบางรักน้อยท่าอิฐ  RapidTransitStation
# 4247  13.7991  100.5750        สถานีรัชดาภิเษก  RapidTransitStation
# 4248  13.6368  100.6099            สถานีทิพวัล  RapidTransitStation
# 4249  13.8062  100.5308            สถานีเตาปูน  RapidTransitStation

# %%
locations.to_csv('data/bangkok_locations.csv', index=False)

# %%
locations['type'].value_counts()
# Out:
# type
# BusStop                3002
# 7-Eleven                842
# place_of_worship        227
# RapidTransitStation     179
# Name: count, dtype: int64
