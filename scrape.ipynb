# %% [markdown]
# # Scrape งบการเงิน

# %%
import requests
from bs4 import BeautifulSoup
import os
import mimetypes

url = "https://data.bangkok.go.th/dataset/2567"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

blocks = soup.find_all("div", class_="bs5-row g-2 justify-content-md-between")
os.makedirs("downloads", exist_ok=True)

for block in blocks:
    title_tag = block.find("h3", class_="body1-medium m-0")
    download_tag = block.find("a", class_="bs5-btn bs5-btn-dark text-decoration-none")
    
    if title_tag and download_tag:
        name = title_tag.text.strip().replace("/", "_")
        download_url = download_tag['href']

        # Head request to guess extension before downloading
        head = requests.head(download_url, allow_redirects=True)
        content_type = head.headers.get("Content-Type", "")
        ext = mimetypes.guess_extension(content_type.split(";")[0].strip()) or ""

        file_path = os.path.join("downloads", f"{name}{ext}")
        if os.path.exists(file_path):
            print(f"✅ Skipping already downloaded: {file_path}")
            continue

        # Download and save
        print(f"⬇️ Downloading: {file_path}")
        r = requests.get(download_url)
        with open(file_path, "wb") as f:
            f.write(r.content)

print("🌟 Done! Skipped already-downloaded files.")
# Out:
# ✅ Skipping already downloaded: downloads/ประมาณการรายรับ 2567.pdf
# ✅ Skipping already downloaded: downloads/รายงานการคลัง 2567.pdf
# ✅ Skipping already downloaded: downloads/ข้อบัญญัติงบประมาณรายจ่ายปี 2567.pdf
# ✅ Skipping already downloaded: downloads/งบประมาณโดยสังเขป.pdf
# ✅ Skipping already downloaded: downloads/จำแนกตามโครงสร้างแผนงานงบประมาณ.pdf
# ✅ Skipping already downloaded: downloads/จำแนกตามยุทธศาสตร์บูรณาการ.pdf
# ✅ Skipping already downloaded: downloads/งบกลาง สำนักงานคณะกรรมการข้าราชการกรุงเทพมหานคร สำนักการคลัง....pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเลขานุการสภากรุงเทพมหานคร สำนักงานเลขานุการผู้ว่าราชการกรุงเทพมหานคร....pdf
# ✅ Skipping already downloaded: downloads/สำนักการระบายน้ำ.pdf
# ✅ Skipping already downloaded: downloads/สำนักสิ่งแวดล้อม.pdf
# ✅ Skipping already downloaded: downloads/สำนักการโยธา.pdf
# ✅ Skipping already downloaded: downloads/สำนักการจราจรและขนส่ง.pdf
# ✅ Skipping already downloaded: downloads/สำนักการวางผังและพัฒนาเมือง.pdf
# ✅ Skipping already downloaded: downloads/สำนักการศึกษา.pdf
# ✅ Skipping already downloaded: downloads/สำนักวัฒนธรรม กีฬา และการท่องเที่ยว.pdf
# ✅ Skipping already downloaded: downloads/สำนักการแพทย์.pdf
# ✅ Skipping already downloaded: downloads/สำนักอนามัย.pdf
# ✅ Skipping already downloaded: downloads/สำนักพัฒนาสังคม.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตพระนคร.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตป้อมปราบศัตรูพ่าย.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสัมพันธวงศ์.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตดุสิต.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตพญาไท.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตห้วยขวาง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตราชเทวี.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตดินแดง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตวังทองหลาง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางรัก.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตปทุมวัน.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตยานนาวา.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตพระโขนง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสาทร.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางคอแหลม.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคลองเตย.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสวนหลวง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตวัฒนา.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางนา.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตธนบุรี.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคลองสาน.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางกอกใหญ่.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางกอกน้อย.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตตลิ่งชัน.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางพลัด.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตจอมทอง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตทวีวัฒนา.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางกะปิ.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตมีนบุรี.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตลาดกระบัง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตหนองจอก.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบึงกุ่ม.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตประเวศ.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคันนายาว.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสะพานสูง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคลองสามวา.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางเขน.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตดอนเมือง.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตจตุจักร.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตลาดพร้าว.pdf
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางซื่อ.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตหลักสี่.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตสายไหม.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตภาษีเจริญ.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตหนองแขม.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตบางขุนเทียน.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตราษฎร์บูรณะ.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตบางแค.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตทุ่งครุ.pdf
# ⬇️ Downloading: downloads/สำนักงานเขตบางบอน.pdf
# ✅ Skipping already downloaded: downloads/มหาวิทยาลัยนวมินทราธิราช.pdf
# ✅ Skipping already downloaded: downloads/การพาณิชย์กรุงเทพมหานคร.pdf
# ⬇️ Downloading: downloads/สำนักการคลัง.xlsx
# ⬇️ Downloading: downloads/สำนักงบประมาณกรุงเทพมหานคร.xls
# ✅ Skipping already downloaded: downloads/สำนักงานคณะกรรมการข้าราชการกรุงเทพมหานคร.xlsx
# ⬇️ Downloading: downloads/สำนักยุทธศาสตร์และประเมินผล.xlsx
# ⬇️ Downloading: downloads/สำนักป้องกันและบรรเทาสาธารณะภัย.xlsx
# ⬇️ Downloading: downloads/สำนักเทศกิจ.xlsx
# ⬇️ Downloading: downloads/สำนักงานเลขานุการผู้ว่ากทม.xlsx
# ⬇️ Downloading: downloads/สำนักปลัดกรุงเทพมหานคร.xlsx
# ✅ Skipping already downloaded: downloads/สำนักการระบายน้ำ.xlsx
# ✅ Skipping already downloaded: downloads/สำนักสิ่งแวดล้อม.xlsx
# ✅ Skipping already downloaded: downloads/สำนักการโยธา.xlsx
# ✅ Skipping already downloaded: downloads/สำนักการจราจรและขนส่ง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักการวางผังและพัฒนาเมือง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักการศึกษา.xls
# ✅ Skipping already downloaded: downloads/สำนักวัฒนธรรม กีฬา และการท่องเที่ยว.xlsx
# ⬇️ Downloading: downloads/สำนักอนามัย.xlsx
# ⬇️ Downloading: downloads/สำนักพัฒนาสังคม.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตพระนคร.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตป้อมปราบศัตรูพ่าย.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสัมพันธวงศ์.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตดุสิต.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตพญาไท.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตห้วยขวาง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตราชเทวี.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตดินแดง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตวังทองหลาง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางรัก.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตปทุมวัน.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตยานนาวา.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตพระโขนง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสาทร.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางคอแหลม.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคลองเตย.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตสวนหลวง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตวัฒนา.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางนา.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตธนบุรี.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตคลองสาน.xls
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางกอกใหญ่.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางกอกน้อย.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตตลิ่งชัน.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางพลัด.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตจอมทอง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตทวีวัฒนา.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบางกะปิ.xls
# ✅ Skipping already downloaded: downloads/สำนักงานเขตมีนบุรี.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตลาดกระบัง.xls
# ⬇️ Downloading: downloads/สำนักงานเขตหนองจอก.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตบึงกุ่ม.xls
# ✅ Skipping already downloaded: downloads/สำนักงานเขตประเวศ.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคันนายาว.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตสะพานสูง.xlsx
# ✅ Skipping already downloaded: downloads/สำนักงานเขตคลองสามวา.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตบางเขน.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตดอนเมือง.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตจตุจักร.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตลาดพร้าว.xls
# ⬇️ Downloading: downloads/สำนักงานเขตหลักสี่.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตบางซื่อ.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตสายไหม.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตภาษีเจริญ.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตหนองแขม.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตบางขุนเทียน.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตราษฎร์บูรณะ.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตบางแค.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตทุ่งครุ.xlsx
# ⬇️ Downloading: downloads/สำนักงานเขตบางบอน.xlsx
# ✅ Skipping already downloaded: downloads/การพาณิชย์.xls
# ✅ Skipping already downloaded: downloads/ม.นวมินทราธิราช.xls
# ⬇️ Downloading: downloads/สำนักการแพทย์.xls
# ⬇️ Downloading: downloads/สำนักงานเลขานุการสภากรุงเทพมหาคร.bin
# 🌟 Done! Skipped already-downloaded files.

# %%
import requests
from bs4 import BeautifulSoup
import re

url = 'https://www.interbangkok.com/bangkok-district/'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')

all_tags = soup.find_all(['p', 'div'])

districts = []
seen = set()

for tag in all_tags:
    text = tag.get_text(separator=' ', strip=True)
    
    
    if 'เขต' in text and 'พื้นที่' in text and 'ประชากร' in text:
        match_district = re.search(r'\d+\.\s*เขต([^\s<]+)', text)
        district_name = match_district.group(1).strip() if match_district else None

        if district_name in seen:
            continue

        match_area = re.search(r'พื้นที่\s*:\s*([\d\.]+)', text)
        area = float(match_area.group(1)) if match_area else None

        match_pop = re.search(r'ประชากร\s*:\s*([\d,]+)', text)
        population = int(match_pop.group(1).replace(',', '')) if match_pop else None

        if district_name and area and population:
            seen.add(district_name)
            districts.append({
                'เขต': district_name,
                'พื้นที่': area,
                'ประชากร': population
            })


districts+=[{'เขต': 'ดุสิต', 'พื้นที่': 10.665, 'ประชากร': 78602}]
print(len(districts))
# Output
for d in districts:
    print(d)
# Out:
# 50
# {'เขต': 'พระนคร', 'พื้นที่': 5.536, 'ประชากร': 41646}
# {'เขต': 'หนองจอก', 'พื้นที่': 236.261, 'ประชากร': 181367}
# {'เขต': 'บางรัก', 'พื้นที่': 5.54, 'ประชากร': 43914}
# {'เขต': 'บางเขน', 'พื้นที่': 42.123, 'ประชากร': 185369}
# {'เขต': 'บางกะปิ', 'พื้นที่': 28.523, 'ประชากร': 141489}
# {'เขต': 'ปทุมวัน', 'พื้นที่': 8.369, 'ประชากร': 40844}
# {'เขต': 'ป้อมปราบศัตรูพ่าย', 'พื้นที่': 1.931, 'ประชากร': 39310}
# {'เขต': 'พระโขนง', 'พื้นที่': 13.986, 'ประชากร': 86290}
# {'เขต': 'มีนบุรี', 'พื้นที่': 63.645, 'ประชากร': 141030}
# {'เขต': 'ลาดกระบัง', 'พื้นที่': 123.859, 'ประชากร': 178350}
# {'เขต': 'ยานนาวา', 'พื้นที่': 16.662, 'ประชากร': 74114}
# {'เขต': 'สัมพันธวงศ์', 'พื้นที่': 1.416, 'ประชากร': 20168}
# {'เขต': 'พญาไท', 'พื้นที่': 9.595, 'ประชากร': 65275}
# {'เขต': 'ธนบุรี', 'พื้นที่': 8.551, 'ประชากร': 99591}
# {'เขต': 'บางกอกใหญ่', 'พื้นที่': 6.18, 'ประชากร': 61579}
# {'เขต': 'ห้วยขวาง', 'พื้นที่': 15.033, 'ประชากร': 83493}
# {'เขต': 'คลองสาน', 'พื้นที่': 6.051, 'ประชากร': 66347}
# {'เขต': 'ตลิ่งชัน', 'พื้นที่': 29.479, 'ประชากร': 101802}
# {'เขต': 'บางกอกน้อย', 'พื้นที่': 11.944, 'ประชากร': 99729}
# {'เขต': 'บางขุนเทียน', 'พื้นที่': 120.687, 'ประชากร': 184805}
# {'เขต': 'ภาษีเจริญ', 'พื้นที่': 17.834, 'ประชากร': 122070}
# {'เขต': 'หนองแขม', 'พื้นที่': 35.825, 'ประชากร': 155243}
# {'เขต': 'ราษฎร์บูรณะ', 'พื้นที่': 15.782, 'ประชากร': 76590}
# {'เขต': 'บางพลัด', 'พื้นที่': 11.36, 'ประชากร': 87475}
# {'เขต': 'ดินแดง', 'พื้นที่': 8.354, 'ประชากร': 111052}
# {'เขต': 'บึงกุ่ม', 'พื้นที่': 24.311, 'ประชากร': 138050}
# {'เขต': 'สาทร', 'พื้นที่': 9.326, 'ประชากร': 72648}
# {'เขต': 'บางซื่อ', 'พื้นที่': 11.545, 'ประชากร': 119431}
# {'เขต': 'จตุจักร', 'พื้นที่': 32.908, 'ประชากร': 153792}
# {'เขต': 'บางคอแหลม', 'พื้นที่': 10.921, 'ประชากร': 79095}
# {'เขต': 'ประเวศ', 'พื้นที่': 52.49, 'ประชากร': 182984}
# {'เขต': 'คลองเตย', 'พื้นที่': 12.994, 'ประชากร': 90446}
# {'เขต': 'สวนหลวง', 'พื้นที่': 23.678, 'ประชากร': 122676}
# {'เขต': 'จอมทอง', 'พื้นที่': 26.265, 'ประชากร': 143330}
# {'เขต': 'ดอนเมือง', 'พื้นที่': 36.803, 'ประชากร': 166289}
# {'เขต': 'ราชเทวี', 'พื้นที่': 7.126, 'ประชากร': 66279}
# {'เขต': 'ลาดพร้าว', 'พื้นที่': 22.157, 'ประชากร': 114275}
# {'เขต': 'วัฒนา', 'พื้นที่': 12.565, 'ประชากร': 80830}
# {'เขต': 'บางแค', 'พื้นที่': 44.456, 'ประชากร': 192253}
# {'เขต': 'หลักสี่', 'พื้นที่': 22.841, 'ประชากร': 100360}
# {'เขต': 'สายไหม', 'พื้นที่': 44.615, 'ประชากร': 208928}
# {'เขต': 'คันนายาว', 'พื้นที่': 25.98, 'ประชากร': 95523}
# {'เขต': 'สะพานสูง', 'พื้นที่': 28.124, 'ประชากร': 96211}
# {'เขต': 'วังทองหลาง', 'พื้นที่': 19.265, 'ประชากร': 104478}
# {'เขต': 'คลองสามวา', 'พื้นที่': 110.686, 'ประชากร': 209120}
# {'เขต': 'บางนา', 'พื้นที่': 18.789, 'ประชากร': 86155}
# {'เขต': 'ทวีวัฒนา', 'พื้นที่': 50.219, 'ประชากร': 79228}
# {'เขต': 'ทุ่งครุ', 'พื้นที่': 30.741, 'ประชากร': 123761}
# {'เขต': 'บางบอน', 'พื้นที่': 34.745, 'ประชากร': 101246}
# {'เขต': 'ดุสิต', 'พื้นที่': 10.665, 'ประชากร': 78602}

# %%
import pandas as pd

# Load your cleaned budget CSV
df = pd.read_csv('data/cleaned_budgets.csv')

# Your previously scraped district data (from earlier step)
scraped_data = districts

# Convert to DataFrame
df_scraped = pd.DataFrame(scraped_data)

# Extract short district name to match easier
df['เขต_clean'] = df['เขต'].str.replace('สำนักงานเขต', '').str.strip()
df_scraped['เขต'] = df_scraped['เขต'].str.strip()

# Merge on cleaned district name
merged = df_scraped.merge(df, left_on='เขต', right_on='เขต_clean', how='right')

# Drop เขต_y and เขต_clean
merged = merged.drop(columns=['เขต_y', 'เขต_clean'])

# Rename เขต_x to เขต
merged = merged.rename(columns={'เขต_x': 'เขต'})

# Optional: save or preview
merged.to_csv('data/area_population_budgets.csv', index=False)
merged.head()
# Out:
#         เขต  พื้นที่  ประชากร  รวมงบประมาณทั้งสิ้น  งานรายจ่ายบุคลากร  \
# 0     วัฒนา   12.565    80830          369693530.0        186276900.0
# 1    บางรัก    5.540    43914          251616775.0        150802100.0
# 2  ลาดพร้าว   22.157   114275          439171770.0        188866120.0
# 3     บางนา   18.789    86155          345957300.0        154865870.0
# 4   หนองแขม   35.825   155243          567238800.0        191069200.0
#
#    งานอำนวยการและบริหารสำนักงานเขต  งานปกครอง  \
# 0                       17822550.0   125100.0
# 1                        5370400.0   831600.0
# 2                       10675560.0   507020.0
# 3                        7322890.0   573600.0
# 4                        8653640.0   532700.0
#
#    งานบริหารทั่วไปและบริการทะเบียน  งานบริหารทั่วไปและบริหารการคลัง  \
# 0                        1015000.0                         865000.0
# 1                        1198600.0                         596500.0
# 2                        1361200.0                         751800.0
# 3                        2281600.0                         659000.0
# 4                        1427000.0                         719600.0
#
#    งานบริหารทั่วไปและจัดเก็บรายได้  ...  งานพัฒนาชุมชนและบริการสังคม  \
# 0                        2132800.0  ...                    7958900.0
# 1                        1419000.0  ...                   14404540.0
# 2                        1309400.0  ...                   17280370.0
# 3                        1912200.0  ...                   11261840.0
# 4                        1567500.0  ...                   51761060.0
#
#    งานบริหารทั่วไปฝ่ายสิ่งแวดล้อมและสุขาภิบาล  \
# 0                                    186600.0
# 1                                    249700.0
# 2                                   1068900.0
# 3                                    120400.0
# 4                                   1142100.0
#
#    งานสุขาภิบาลอาหารและอนามัยสิ่งแวดล้อม  งานป้องกันและควบคุมโรค  \
# 0                              1030000.0                 10000.0
# 1                              1021400.0                 11200.0
# 2                               193860.0                     0.0
# 3                               303000.0               6695100.0
# 4                               124600.0                 11700.0
#
#    งานบริหารทั่วไปฝ่ายการศึกษา  งานงบประมาณโรงเรียน  \
# 0                     909000.0           51900880.0
# 1                     263000.0           22628500.0
# 2                     693200.0           94806420.0
# 3                    4737100.0            8229300.0
# 4                     625500.0          131041960.0
#
#    โครงการจ้างงานคนพิการเพื่อปฏิบัติงาน  โครงการครอบครัวรักการอ่าน  \
# 0                             1134000.0                   120000.0
# 1                             1134000.0                        0.0
# 2                             1134000.0                   120000.0
# 3                             1134000.0                    50000.0
# 4                             1134000.0                        0.0
#
#    โครงการการจัดสวัสดิการ การสงเคราะห์ช่วยเหลือเด็ก สตรี ครอบครัว ผู้ด้อยโอกาส ผู้สูงอายุ และคนพิการ  \
# 0                                           225500.0
# 1                                           275000.0
# 2                                           300000.0
# 3                                          1350000.0
# 4                                          1000000.0
#
#    โครงการบูรณาการความร่วมมือในการพัฒนาประสิทธิภาพการแก้ไขปัญหาโรคไข้เลือดออกในพื้นที่กรุงเทพมหานคร
# 0                                            87100.0
# 1                                            69600.0
# 2                                           301360.0
# 3                                           180900.0
# 4                                           232800.0
#
# [5 rows x 31 columns]
